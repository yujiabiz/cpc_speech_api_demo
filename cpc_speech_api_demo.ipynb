# %%
# !pip install google.cloud.speech
# Out:
# Collecting google.cloud.speech
#   Using cached google_cloud_speech-0.29.0-py2.py3-none-any.whl
# Requirement already satisfied: google-gax<0.16dev,>=0.15.14 in /usr/local/lib/python2.7/dist-packages (from google.cloud.speech)
# Requirement already satisfied: google-cloud-core<0.28dev,>=0.27.0 in /usr/local/lib/python2.7/dist-packages (from google.cloud.speech)
# Requirement already satisfied: googleapis-common-protos[grpc]<2.0dev,>=1.5.2 in /usr/local/lib/python2.7/dist-packages (from google.cloud.speech)
# Requirement already satisfied: google-auth<2.0dev,>=1.0.0 in /usr/local/lib/python2.7/dist-packages (from google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: future<0.17dev,>=0.16.0 in /usr/local/lib/python2.7/dist-packages (from google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: dill<0.3dev,>=0.2.5 in /usr/local/lib/python2.7/dist-packages (from google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: grpcio<1.6dev,>=1.0.2 in /usr/local/lib/python2.7/dist-packages (from google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: ply==3.8 in /usr/local/lib/python2.7/dist-packages (from google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: protobuf<4.0dev,>=3.0.0 in /usr/local/lib/python2.7/dist-packages (from google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: requests<3.0dev,>=2.13.0 in /usr/local/lib/python2.7/dist-packages (from google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: futures>=3.0.0; python_version < "3.2" in /usr/local/lib/python2.7/dist-packages (from google-cloud-core<0.28dev,>=0.27.0->google.cloud.speech)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python2.7/dist-packages (from google-cloud-core<0.28dev,>=0.27.0->google.cloud.speech)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/local/lib/python2.7/dist-packages (from google-cloud-core<0.28dev,>=0.27.0->google.cloud.speech)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0dev,>=1.0.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0dev,>=1.0.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0dev,>=1.0.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0dev,>=1.0.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: enum34>=1.0.4 in /usr/local/lib/python2.7/dist-packages (from grpcio<1.6dev,>=1.0.2->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests<3.0dev,>=2.13.0->google-gax<0.16dev,>=0.15.14->google.cloud.speech)
# Installing collected packages: google.cloud.speech
# Successfully installed google.cloud.speech

# %%
# !pip install google.cloud.core
# Out:
# Collecting google.cloud.core
#   Using cached google_cloud_core-0.27.1-py2.py3-none-any.whl
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python2.7/dist-packages (from google.cloud.core)
# Requirement already satisfied: futures>=3.0.0; python_version < "3.2" in /usr/local/lib/python2.7/dist-packages (from google.cloud.core)
# Requirement already satisfied: google-auth<2.0.0dev,>=0.4.0 in /usr/local/lib/python2.7/dist-packages (from google.cloud.core)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python2.7/dist-packages (from google.cloud.core)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python2.7/dist-packages (from google.cloud.core)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/local/lib/python2.7/dist-packages (from google.cloud.core)
# Requirement already satisfied: googleapis-common-protos>=1.3.4 in /usr/local/lib/python2.7/dist-packages (from google.cloud.core)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google.cloud.core)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google.cloud.core)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google.cloud.core)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google.cloud.core)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0.0dev,>=0.4.0->google.cloud.core)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0.0dev,>=0.4.0->google.cloud.core)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0.0dev,>=0.4.0->google.cloud.core)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python2.7/dist-packages (from google-auth<2.0.0dev,>=0.4.0->google.cloud.core)
# Installing collected packages: google.cloud.core
# Successfully installed google.cloud.core

# %%
import argparse
import io
import google.datalab.storage as storage

# %%
def short_transcribe_gcs(gcs_uri):
    """Transcribes the audio file specified by the gcs_uri."""
    from google.cloud import speech
    from google.cloud.speech import enums
    from google.cloud.speech import types
    client = speech.SpeechClient()

    # [START migration_audio_config_gcs]
    audio = types.RecognitionAudio(uri=gcs_uri)
    config = types.RecognitionConfig(
        language_code='en-US')
    # [END migration_audio_config_gcs]

    response = client.recognize(config, audio)
    # return the first alternative of all the consecutive results.
    res = list()
    for result in response.results:
        res.append(result.alternatives[0].transcript)
    return '\n'.join(res)

# %%
def long_transcribe_gcs(gcs_uri):
    """Asynchronously transcribes the audio file specified by the gcs_uri."""
    from google.cloud import speech
    from google.cloud.speech import enums
    from google.cloud.speech import types
    client = speech.SpeechClient()

    audio = types.RecognitionAudio(uri=gcs_uri)
    config = types.RecognitionConfig(
        language_code='en-US')

    operation = client.long_running_recognize(config, audio)

    print('Waiting for operation to complete...')
    response = operation.result(timeout=90)

    # return the first alternative of all the consecutive results.
    res = ""
    res = list()
    for result in response.results:
        res.append(result.alternatives[0].transcript)
    return '\n'.join(res)

# %%
def findWordsWithDistance(words, word1, word2, distance):
    """
    :type words: List[str]
    :type word1: str
    :type word2: str
    :rtype: int
    """
    m=len(words)
    p1=-len(words)
    p2=len(words)
    for i in range(0,len(words)):
        if word1[-1] == '!':
            if words[i] == word1:
                p1=i
        else:
            if word1 in words[i].lower():
                p1=i
        if word2[-1] == '!':
            if words[i] == word2:
                p2=i
        else:
            if word2 in words[i].lower():
                p2=i
        m=min(m,abs(p1-p2))
    if m <= distance:
        return True
    return False

# %%
def phrase_search(text, phrase):
    distance = int(phrase.split('~')[1])
    word1 = phrase.split('~')[0].split()[0]
    word2 = phrase.split('~')[0].split()[1]
    return findWordsWithDistance(text.split(), word1, word2, distance)

# %%
def word_search(text, word):
    if word[-1] == '!':
        for i in text.split():
            if i == word:
                return True
        return False
    else:
        return word.lower() in text.lower()

# %%
def condition_search(text, terms):
    term_list_1 = terms.split(' AND ')[0].split(',')
    term_list_2 = terms.split(' AND ')[1].split(',')
    for i in term_list_1:
        first_check = False
        if '~' in i:
            first_check = phrase_search(text, i)
        else:
            first_check = word_search(text, i)
        if first_check:
            second_check = False
            for j in term_list_2:
                if '~' in j:
                    second_check = phrase_search(text, j)
                else:
                    second_check = word_search(text, j)
                if second_check:
                    return True
    return False

# %%
def tag_text(text):
    tag_list = list()
    for i in range(0,len(ontology)):
        tag = True
        and_check = ['Keywords', 'And Words', 'And Words (2)']
        not_check = 'Not Words'
        continue_check = True
        for a in and_check:
            if str(ontology[a].values[i]) != 'nan':
                a_check = False
                for wds in ontology[a].values[i].split('|'):
                    print(wds)
                    if 'AND' in wds:
                        a_check = condition_search(text, wds)
                        if a_check:
                            break
                    else: 
                        for sub_wds in wds.split(','):
                            if '~' in sub_wds:
                                a_check = phrase_search(text, sub_wds)
                            elif len(sub_wds) != 0:
                                a_check = word_search(text, sub_wds)
                            if a_check:
                                break
            if not a_check:
                tag = False
                continue_check = False
                break
        if continue_check:
            if str(ontology[not_check].values[i]) != 'nan':
                n_check = False
                for wds in ontology[not_check].values[i].split('|'):
                    if 'AND' in wds:
                        n_check = condition_search(text, wds)
                        if n_check:
                                tag = False
                                break
                    else: 
                        for sub_wds in wds.split(','):
                            if '~' in sub_wds:
                                n_check = phrase_search(text, sub_wds)
                            elif len(sub_wds) != 0:
                                n_check = word_search(text, sub_wds)
                            if n_check:
                                tag = False
                                break
        if tag:
            tag_list.append(i)
    return ontology.iloc[tag_list,]

# %%
sample_bucket = storage.Bucket('cpc-speech-analytics-demo')
complaints = list()
for i in sample_bucket.objects():
    if str(i)[-3:] == 'wav' and 'long-audio' not in str(i):
        complaints.append(short_transcribe_gcs(str(i)[28:]))
    if str(i)[-3:] == 'wav' and 'long-audio' in str(i):
        complaints.append(long_transcribe_gcs(str(i)[28:]))

# %%
complaints
# Out:
# [u"I opened an account online but never received my account opening disclosures unless I am mistaken they never mailed emailed or stored them electronically on online banking I called the call center to find out where I could get them she told me I would receive them by mail in 10 business days will I still don't have to disclose your how am I supposed to know to avoid a fee if I don't have the disclosures",
# %%
import pandas as pd
import numpy as np

# %%
import datalab.data
import sys  
reload(sys)  
sys.setdefaultencoding('utf8')

# %%
csv = datalab.data.Csv('gs://cpc-speech-analytics-demo/ontology_demo.csv',delimiter=';')

# %%
ontology = csv.browse()

# %%
ontology.columns = ontology.iloc[0,]
ontology = ontology.iloc[1:,1:]

# %%
def tagging(complaints):
    tagged_cp = pd.DataFrame()
    columns = ['Complaint ID', 'Complaint', 'Regulation', 'Theme ID', 'Theme Name', 'Section', 'Plain Language Description']
    for c in complaints:
        res = tag_text(c)
        if res.empty:
            res = pd.DataFrame.transpose(pd.DataFrame.from_dict({'Complaint ID': complaints.index(c), 'Complaint': c, 'Regulation': None, 'Theme ID': None, 'Theme Name': None, 'Section': None, 'Plain Language Description': None}, 'index'))
        else:
            res['Complaint'] = c
            res['Complaint ID'] = complaints.index(c)
            res = res[columns]
        if tagged_cp.empty:
            tagged_cp = res
        else:
            tagged_cp = tagged_cp.append(res,ignore_index=True)
    return tagged_cp

# %%
tagging([i for i in complaints if i is not None])
# Out:
#                                             Complaint Complaint ID  \
# 0   I opened an account online but never received ...            0
# 1   I have used this fence credit card check for 3...            1
# 2   I am continually being charged overdraft fees ...            2
# 3   my bank continuously refuses to honor my reque...            3
# 4   I never opting to overdraft protection and hav...            4
# 5   after By Number beds eligible product from thi...            5
# 6   I requested International wire transfer at thi...            6
# 7   I requested International wire transfer at thi...            6
# 8   I sent an international wire transfer through ...            7
# 9   I sent an international wire transfer through ...            7
# 10  I did not receive a bill for my store card I c...            8
# 11  I opened up a charge card through this bank fo...            9
# 12  my loan and service to Balance Financial Servi...           10
# 13  Malone a service by this financial service com...           11
# 14  Malone a service by this financial service com...           11
# 15  I have monthly payments under my current IBI c...           12
# 16  complaining against this company for not on th...           13
# 17  welcome to the Main Street Bank my name is Jen...           14
# 18  I close my bank account at the branch and was ...           15
# 19  I am a single parent on July 20th 2013 I co-si...           16
# 20  I am a single parent on July 20th 2013 I co-si...           16
# 21  I am a single parent on July 20th 2013 I co-si...           16
# 22  July 9th 2017 I applied for business credit ca...           17
# 23  July 9th 2017 I applied for business credit ca...           17
#
#                            Plain Language Description  \
# 0   § 1026.5 General disclosure requirements\nMake...
# 1   § 1026.5 General disclosure requirements\nMake...
# 2   Consumer must opt in to overdraft services, an...
# 3                                                None
# 4                                                None
# 5   § 1026.5 General disclosure requirements\nMake...
# 6   Disclosure, notice, and accuracy requirements ...
# 7   § 1026.5 General disclosure requirements\nMake...
# 8   Disclosure, notice, and accuracy requirements ...
# 9   § 1026.5 General disclosure requirements\nMake...
# 10                                                NaN
# 11                                                NaN
# 12                                               None
# 13  §1005.10, (a) (1)-(2) Preauthorized transfers ...
# 14  § 1026.10 Payments \nCredit a payment to the c...
# 15  §1005.10, (c) Consumer's right to stop payment...
# 16  §1005.10, (c) Consumer's right to stop payment...
# 17  §1005.10, (c) Consumer's right to stop payment...
# 18                                               None
# 19  § 1026.5 General disclosure requirements\nMake...
# 20  § 1026.9(h) Consumer rejection of changes in t...
# 21  § 1026.10(e) Limitations on fees related to me...
# 22  Timing of notifications\nA creditor must notif...
# 23                                          See above
#
#                  Regulation  \
# 0               Reg Z: TILA
# 1               Reg Z: TILA
# 2               Reg E: EFTA
# 3                      None
# 4                      None
# 5               Reg Z: TILA
# 6               Reg E: EFTA
# 7               Reg Z: TILA
# 8               Reg E: EFTA
# 9               Reg Z: TILA
# 10              Reg Z: TILA
# 11              Reg Z: TILA
# 12                     None
# 13              Reg E: EFTA
# 14              Reg Z: TILA
# 15              Reg E: EFTA
# 16              Reg E: EFTA
# 17              Reg E: EFTA
# 18                     None
# 19              Reg Z: TILA
# 20              Reg Z: TILA
# 21              Reg Z: TILA
# 22  Fair Lending (ECOA/FHA)
# 23              Reg Z: TILA
#
#                                               Section Theme ID  \
# 0                § 1026.6 Account-opening disclosures        1
# 1   § 1026.5 General disclosure requirements\n§ 10...        1
# 2        §1005.17 Requirements for overdraft services       11
# 3                                                None     None
# 4                                                None     None
# 5   § 1026.5 General disclosure requirements\n§ 10...        1
# 6   §1005.36 Transfers scheduled before the date o...       13
# 7   § 1026.5 General disclosure requirements\n§ 10...        1
# 8   §1005.36 Transfers scheduled before the date o...       13
# 9                        § 1026.9(c) Change in terms         1
# 10  § 1026.12(d) Offsets by card issuer prohibited...       22
# 11  § 1026.12(d) Offsets by card issuer prohibited...       22
# 12                                               None     None
# 13  §1005.6 Liability of consumer\nSTATEMENTS / NO...        4
# 14  § 1026.10 Payments \n§ 1026.13(d)(1) Consumer’...        5
# 15  §1005.10(c) Consumer’s right to stop payment (...        7
# 16  §1005.10(c) Consumer’s right to stop payment (...        7
# 17  §1005.10(c) Consumer’s right to stop payment (...        7
# 18                                               None     None
# 19  § 1026.5 General disclosure requirements\n§ 10...        1
# 20  § 1026.9(h) Consumer rejection of change in terms        3
# 21  § 1026.10(e) Limitations on fees related to me...        6
# 22  12 CFR §1002.9(a) Notifications of action take...        6
# 23  § 1026.60 Credit and charge card applications ...        1
#
#                       Theme Name
# 0          DISCLOSURES / NOTICES
# 1          DISCLOSURES / NOTICES
# 2                 OVERDRAFT FEES
# 3                           None
# 4                           None
# 5          DISCLOSURES / NOTICES
# 6           REMITTANCE TRANSFERS
# 7          DISCLOSURES / NOTICES
# 8           REMITTANCE TRANSFERS
# 9          DISCLOSURES / NOTICES
# 10  PROHIBITED ACTS OR PRACTICES
# 11  PROHIBITED ACTS OR PRACTICES
# 12                          None
# 13                     LIABILITY
# 14                      PAYMENTS
# 15   STOP PAYMENT / CANCELLATION
# 16   STOP PAYMENT / CANCELLATION
# 17   STOP PAYMENT / CANCELLATION
# 18                          None
# 19         DISCLOSURES / NOTICES
# 20  REJECTION OF CHANGE IN TERMS
# 21                          FEES
# 22         ADVERSE ACTION NOTICE
# 23         DISCLOSURES / NOTICES
